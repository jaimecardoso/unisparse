# %%
from google.colab import drive
drive.mount('/content/drive')

# %pwd
# %ls

# %cd "/content/directory_name"
# Out:
# Mounted at /content/drive
# drive/  sample_data/
# [Errno 2] No such file or directory: '/content/directory_name'
# /content

# %%
# %cd "drive/My Drive/Colab Notebooks/unisparse"
# %pwd


# THE CODE THAT FOLLOWS IS INCOMPLETE, TOTALLY MESSY AND PROVIDED WITHOUT ANY GUARANTEE
# Out:
# /content/drive/My Drive/Colab Notebooks/unisparse
# '/content/drive/My Drive/Colab Notebooks/unisparse'

# %%
# %run ordinal_experiment.py
# Out:
# Torch: 2.11.0+cpu
# CUDA available: False
#
# ...
# Dataset: NewThyroid
#   n=215, K=3, dist=[150, 35, 30]
# Sparsemax
# fold 0  training set size  138
#   epoch   0/1000 validation loss=1.0294
#   epoch 350/1000 validation loss=1.4118
#   epoch 700/1000 validation loss=1.4412
# fold 1  training set size  138
#   epoch   0/1000 validation loss=1.5000
#   epoch 350/1000 validation loss=1.5294
#   epoch 700/1000 validation loss=1.5294
# fold 2  training set size  138
#   epoch   0/1000 validation loss=1.4118
#   epoch 350/1000 validation loss=1.5000
#   epoch 700/1000 validation loss=1.4706
# fold 3  training set size  138
#   epoch   0/1000 validation loss=1.5882
#   epoch 350/1000 validation loss=1.5294
#   epoch 700/1000 validation loss=1.5294
# fold 4  training set size  138
#   epoch   0/1000 validation loss=0.2941
#   epoch 350/1000 validation loss=1.5882
#   epoch 700/1000 validation loss=1.5882
# fold 0  training set size  138
#   epoch   0/1000 validation loss=0.4412
# ...
